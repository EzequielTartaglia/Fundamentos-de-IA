# %% [markdown]
# # Conceptos basicos de Fotografia

# %% [markdown]
# ### Tipos de plano segun escala

# %% [markdown]
# ![Fotografia - Planos.png](<attachment:Fotografia - Planos.png>)

# %% [markdown]
# ### Iluminacion y sentimientos a traves de la iluminación

# %% [markdown]
# ![Fotografia - Iluminacion Grados Kelvin.png](<attachment:Fotografia - Iluminacion Grados Kelvin.png>)

# %% [markdown]
# ![Fotografia - Iluminacion Grados Kelvin Ejemplos.png](<attachment:Fotografia - Iluminacion Grados Kelvin Ejemplos.png>)

# %% [markdown]
# ![Fotografia - Iluminacion Grados Kelvin Ejemplo.png](<attachment:Fotografia - Iluminacion Grados Kelvin Ejemplo.png>)
